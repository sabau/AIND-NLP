# %% [markdown]
# # Text Processing
#
# ## Capturing Text Data
#
# ### Plain Text

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
import os

# Read in a plain text file
with open(os.path.join("data", "hieroglyph.txt"), "r") as f:
    text = f.read()
    print(text)
# Out:
# Hieroglyphic writing dates from c. 3000 BC, and is composed of hundreds of symbols. A hieroglyph can represent a word, a sound, or a silent determinative; and the same symbol can serve different purposes in different contexts. Hieroglyphs were a formal script, used on stone monuments and in tombs, that could be as detailed as individual works of art.

# %% [markdown]
# ### Tabular Data

# %%
import pandas as pd

# Extract text column from a dataframe
df = pd.read_csv(os.path.join("data", "news.csv"))
df.head()[['publisher', 'title']]

# Convert text column to lowercase
df['title'] = df['title'].str.lower()
df.head()[['publisher', 'title']]
# Out:
#       publisher                                              title
# 0      Livemint  fed's charles plosser sees high bar for change...
# 1  IFA Magazine  us open: stocks fall after fed official hints ...
# 2  IFA Magazine  fed risks falling 'behind the curve', charles ...
# 3     Moneynews  fed's plosser: nasty weather has curbed job gr...
# 4        NASDAQ  plosser: fed may have to accelerate tapering pace

# %% [markdown]
# ### Online Resource

# %%
import requests
import json

# Fetch data from a REST API
r = requests.get(
    "https://quotes.rest/qod.json")
res = r.json()
print(json.dumps(res, indent=4))

# Extract relevant object and field
q = res["contents"]["quotes"][0]
print(q["quote"], "\n--", q["author"])
# Out:
# {
#     "success": {
#         "total": 1
#     },
#     "contents": {
#         "quotes": [
#             {
#                 "quote": "It's not whether you get knocked down, it...s whether you get up.",
#                 "length": "65",
#                 "author": "Vince Lombardi",
#                 "tags": [
#                     "failure",
#                     "inspire",
#                     "learning-from-failure"
#                 ],
#                 "category": "inspire",
#                 "date": "2018-02-05",
#                 "permalink": "https://theysaidso.com/quote/06Qdox8w6U3U1CGlLqRwFAeF/768262-vince-lombardi-its-not-whether-you-get-knocked-down-its-whether-you-get-up",
#                 "title": "Inspiring Quote of the day",
#                 "background": "https://theysaidso.com/img/bgs/man_on_the_mountain.jpg",
#                 "id": "06Qdox8w6U3U1CGlLqRwFAeF"
#             }
#         ],
#         "copyright": "2017-19 theysaidso.com"
#     }
# }
# It's not whether you get knocked down, it...s whether you get up.
# -- Vince Lombardi

# %% [markdown]
# ## Cleaning

# %%
import requests
from selenium import webdriver

options = webdriver.ChromeOptions()
options.add_argument("--headless")  
options.binary_location = '/usr/bin/google-chrome-stable'
driver = webdriver.Chrome(chrome_options=options) 

driver.get('https://eu.udacity.com/courses/all')
driver.set_window_size(1280, 640)
r = driver.page_source #find_element_by_xpath("/").get_attribute('innerHTML')

# # Fetch a web page
# r = requests.get("https://www.udacity.com/courses/all")
print(r)
driver.quit()
# Out:
# <!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml"><head><meta charset="utf-8" /><title>Catalog | Udacity</title><base href="/" /><meta name="viewport" content="width=device-width,initial-scale=1" /><link rel="icon" type="image/x-icon" href="favicon.ico" /><script type="text/javascript" async="" src="https://www.google-analytics.com/plugins/ua/linkid.js"></script><script type="text/javascript" async="" src="https://d3qxef4rp70elm.cloudfront.net/m.js"></script><script src="https://connect.facebook.net/signals/config/823398221086645?v=2.8.10&amp;r=stable" async=""></script><script type="text/javascript" async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://cdn.segment.com/analytics.js/v1/YsFs6DzVbI40tRSPB50ACV48CcxmSvfR/analytics.min.js"></script><script src="/assets/vendor/segment.js" async=""></script><link href="styles.92f29c1253ee570886d4.bundle.css" rel="stylesheet" /><meta name="og:title" content="Catalog | Udacity" /><meta name="twitter:title" content="Catalog | Udacity" /><meta name="description" content="All Courses and Nanodegree Programs" /><meta name="og:description" content="All Courses and Nanodegree Programs" /><meta name="twitter:description" content="All Courses and Nanodegree Programs" /><link rel="alternate" hreflang="en-AT" href="https://eu.udacity.com/courses/all" /><link rel="alternate" hreflang="en-ES" href="https://eu.udacity.com/courses/all" /><link rel="alternate" hreflang="en-FR" href="https://eu.udacity.com/courses/all" /><link rel="alternate" hreflang="en-IE" href="https://eu.udacity.com/courses/all" /><link rel="alternate" hreflang="en-IT" href="https://eu.udacity.com/courses/all" /><link rel="alternate" hreflang="en-EG" href="https://eg.udacity.com/courses/all" /><link rel="alternate" hreflang="zh-CN" href="https://cn.udacity.com/courses/all" /><link rel="alternate" hreflang="de" href="https://de.udacity.com/courses/all" /><link rel="alternate" hreflang="en-SA" href="https://sa.udacity.com/courses/all" /><link rel="alternate" hreflang="en" href="https://www.udacity.com/courses/all" /><link rel="alternate" hreflang="en-AE" href="https://ae.udacity.com/courses/all" /><link rel="alternate" hreflang="pt-BR" href="https://br.udacity.com/courses/all" /><link rel="alternate" hreflang="en-IN" href="https://in.udacity.com/courses/all" /><script async="" src="https://static.leaddyno.com/js"></script><script type="text/javascript" charset="utf-8" async="" src="0.056f29c3e5b805163df7.chunk.js"></script><script type="text/javascript" charset="utf-8" async="" src="1.98f4a70550984113be3e.chunk.js"></script><script async="" src="https://static.hotjar.com/c/hotjar-694336.js?sv=5"></script><script type="text/javascript" src="//ajax.googleapis.com/ajax/libs/jquery/1.10.1/jquery.min.js"></script><style>html[_ngcontent-c0]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c0], [_ngcontent-c0]:after, [_ngcontent-c0]:before{-webkit-box-sizing:inherit;box-sizing:inherit}a[_ngcontent-c0]{color:#9400d3}body[_ngcontent-c0]{color:#028bb1}[_nghost-c0]{display:block;position:relative}</style><style>html[_ngcontent-c1]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c1], [_ngcontent-c1]:after, [_ngcontent-c1]:before{-webkit-box-sizing:inherit;box-sizing:inherit}.invisible[_ngcontent-c1]{visibility:hidden!important}.hide[_ngcontent-c1]{display:none!important}.show[_ngcontent-c1]{display:block!important}.sr-only[_ngcontent-c1]{height:1px;width:1px;overflow:hidden;position:absolute!important;clip:rect(1px,1px,1px,1px)}.hidden-xs-up[_ngcontent-c1]{display:none!important}@media (max-width:479px){.hidden-xs-down[_ngcontent-c1]{display:none!important}}@media (min-width:480px){.hidden-sm-up[_ngcontent-c1]{display:none!important}}@media (max-width:767px){.hidden-sm-down[_ngcontent-c1]{display:none!important}}@media (min-width:768px ...
#
# html[_ngcontent-c14]{font-family:sans-serif;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}footer[_ngcontent-c14], header[_ngcontent-c14], nav[_ngcontent-c14], section[_ngcontent-c14]{display:block}a[_ngcontent-c14]{background:0 0;color:#1f8fc1;text-decoration:none}a[_ngcontent-c14]:active, a[_ngcontent-c14]:hover{outline:0}strong[_ngcontent-c14]{font-weight:700}h1[_ngcontent-c14]{margin:.67em 0}body[_ngcontent-c14]{background-color:#fff}img[_ngcontent-c14]{vertical-align:middle}svg[_ngcontent-c14]:not(:root){overflow:hidden}hr[_ngcontent-c14]{-webkit-box-sizing:content-box;box-sizing:content-box;height:0}input[_ngcontent-c14]{color:inherit;font:inherit;margin:0}input[type=submit][_ngcontent-c14]{-webkit-appearance:button;cursor:pointer}input[_ngcontent-c14]::-moz-focus-inner{border:0;padding:0}input[type=checkbox][_ngcontent-c14]{-webkit-box-sizing:border-box;box-sizing:border-box;padding:0}input[type=search][_ngcontent-c14]::-webkit-search-cancel-button, input[type=search][_ngcontent-c14]::-webkit-search-decoration{-webkit-appearance:none}*[_ngcontent-c14], [_ngcontent-c14]:after, [_ngcontent-c14]:before{-webkit-box-sizing:border-box;box-sizing:border-box}body[_ngcontent-c14]{margin:0;font-size:14px;line-height:1.7;color:#303030}input[_ngcontent-c14]{font-family:inherit;font-size:inherit;line-height:inherit}a[_ngcontent-c14]:focus, a[_ngcontent-c14]:hover{color:#145e7f}a[_ngcontent-c14]:focus{outline:thin dotted;outline:5px auto -webkit-focus-ring-color;outline-offset:-2px}.img-responsive[_ngcontent-c14]{display:block;max-width:100%;height:auto}hr[_ngcontent-c14]{margin-top:23px;margin-bottom:23px;border-top:1px solid #dcdcdc}.h4[_ngcontent-c14], h1[_ngcontent-c14], h3[_ngcontent-c14], h4[_ngcontent-c14], h6[_ngcontent-c14]{font-family:inherit;font-weight:700;line-height:1.1;color:inherit}h1[_ngcontent-c14], h3[_ngcontent-c14]{margin-top:23px}.h4[_ngcontent-c14], h1[_ngcontent-c14], h3[_ngcontent-c14], h4[_ngcontent-c14], h6[_ngcontent-c14]{margin-bottom:11.5px}.h4[_ngcontent-c14], h4[_ngcontent-c14], h6[_ngcontent-c14]{margin-top:11.5px}ul[_ngcontent-c14]{margin-top:0}h1[_ngcontent-c14]{font-size:28px}h3[_ngcontent-c14]{font-size:18px}.h4[_ngcontent-c14], h4[_ngcontent-c14], h6[_ngcontent-c14]{font-size:12px}ul[_ngcontent-c14]   ul[_ngcontent-c14]{margin-bottom:0}label[_ngcontent-c14]{font-weight:700}.small[_ngcontent-c14]{font-size:85%}.text-right[_ngcontent-c14]{text-align:right}.text-center[_ngcontent-c14]{text-align:center}.h4[_ngcontent-c14], .text-uppercase[_ngcontent-c14], h4[_ngcontent-c14]{text-transform:uppercase}ul[_ngcontent-c14]{margin-bottom:11.5px}@media (min-width:768px){.container[_ngcontent-c14]{width:750px}}.container[_ngcontent-c14]:after, .row[_ngcontent-c14]:after{clear:both}.container[_ngcontent-c14]{margin-right:auto;margin-left:auto;padding-left:15px;padding-right:15px}@media (min-width:992px){.container[_ngcontent-c14]{width:970px}}@media (min-width:1200px){.container[_ngcontent-c14]{width:1200px}}.row[_ngcontent-c14]{margin-left:-15px;margin-right:-15px}.col-sm-3[_ngcontent-c14], .col-sm-4[_ngcontent-c14], .col-sm-6[_ngcontent-c14], .col-sm-8[_ngcontent-c14], .col-sm-9[_ngcontent-c14], .col-sm-12[_ngcontent-c14], .col-xs-8[_ngcontent-c14], .col-xs-12[_ngcontent-c14]{position:relative;min-height:1px;padding-left:15px;padding-right:15px}.col-xs-8[_ngcontent-c14], .col-xs-12[_ngcontent-c14]{float:left}.col-xs-12[_ngcontent-c14]{width:100%}.col-xs-8[_ngcontent-c14]{width:66.66666667%}.col-xs-offset-2[_ngcontent-c14]{margin-left:16.66666667%}@media (min-width:768px){.col-sm-3[_ngcontent-c14], .col-sm-4[_ngcontent-c14], .col-sm-6[_ngcontent-c14], .col-sm-8[_ngcontent-c14], .col-sm-9[_ngcontent-c14], .col-sm-12[_ngcontent-c14]{float:left}.col-sm-12[_ngcontent-c14]{width:100%}.col-sm-9[_ngcontent-c14]{width:75%}.col-sm-8[_ngcontent-c14]{width:66.66666667%}.col-sm-6[_ngcontent-c14]{width:50%}.col-sm-4[_ngcontent-c14]{width:33.33333333%}.col-sm-3[_ngcontent-c14]{width:25%}.col-sm-offset-0[_ngconten ...
# .text-inverse[_ngcontent-c14]{color:#fff}@font-face{font-family:Whitney SSm A;src:url(data:application/x-font-woff;base64,...);font-weight:400;font-style:normal}@font-face{font-family:Whitney SSm B;src:url(data:application/x-font-woff;base64,...);font-weight:400;font-style:normal}@font-face{font-family:Whitney SSm A;src:url(data:application/x-font-woff;base64,...);font-weight:600;font-style:normal}@font-face{font-family:Whitney SSm B;src:url(data:application/x-font-woff;base64,...);font-weight:600;font-style:normal}[data-cloak][_ngcontent-c14]{display:none}.row.row-gap-medium[_ngcontent-c14]{margin-top:30px}.row.row-gap-large[_ngcontent-c14]{margin-top:45px}.section-inverse[_ngcontent-c14]{padding-top:60px;padding-bottom:60px}.section-inverse.section-small[_ngcontent-c14]{padding-top:30px;padding-bottom:30px}.section-inverse[_ngcontent-c14]{background-color:#4e4e4e}.section-inverse.section-inverse-standout-alternate[_ngcontent-c14]{background-color:#1f8fc1}.icon-level[_ngcontent-c14]{display:inline-block;height:12px;width:12px;margin-left:28px;background-color:#dcdcdc;position:relative}.icon-level[_ngcontent-c14]:after, .icon-level[_ngcontent-c14]:before{position:absolute;bottom:0;content:"";display:block;width:12px;background-color:inherit}.icon-level[_ngcontent-c14]:before{height:12px;left:-14px}.icon-level[_ngcontent-c14]:after{height:12px;left:-28px}.icon-level.icon-level-advanced[_ngcontent-c14], .icon-level.icon-level-anfänger[_ngcontent-c14]:after, .icon-level.icon-level-beginner[_ngcontent-c14]:after, .icon-level.icon-level-fortgeschrittene[_ngcontent-c14]:after, .icon-level.icon-level-fortgeschrittene[_ngcontent-c14]:before, .icon-level.icon-level-intermediate[_ngcontent-c14]:after, .icon-level.icon-level-intermediate[_ngcontent-c14]:before, .icon-level.icon-level-profis[_ngcontent-c14]{background-color:#666}.img-bordered[_ngcontent-c14]{border:1px solid #f3f3f3}.top_banner[_ngcontent-c14]{font-family:Open Sans,sans-serif}.top_banner[_ngcontent-c14]   p[_ngcontent-c14]   a[_ngcontent-c14]{text-decoration:none}.course-summary-card[_ngcontent-c14], .course-summary-card[_ngcontent-c14]   img[_ngcontent-c14]{-webkit-transition:opacity .3s ease-in;transition:opacity .3s ease-in}@media (max-width:767px){.course-summary-card[_ngcontent-c14]   h3[_ngcontent-c14]{text-align:center}.course-summary-card[_ngcontent-c14]   .badges[_ngcontent-c14]{display:block;text-align:center}}.contain[_ngcontent-c14]{margin:0 auto}.top_banner[_ngcontent-c14]{display:none;font-size:16px;-webkit-font-smoothing:antialiased;position:relative;background:#7d97ad;padding:.5em 1.5em;text-align:center}.top_banner[_ngcontent-c14]   p[_ngcontent-c14]{position:relative;color:#fff;font-size:.875em;margin:0;line-height:1.5em}.top_banner[_ngcontent-c14]   p[_ngcontent-c14
pattern = re.compile(r'<.*?>')  # tags look like <...>
print(pattern.sub('', r))  # replace them with blank
# Out:
# Catalog | Udacityhtml[_ngcontent-c0]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c0], [_ngcontent-c0]:after, [_ngcontent-c0]:before{-webkit-box-sizing:inherit;box-sizing:inherit}a[_ngcontent-c0]{color:#9400d3}body[_ngcontent-c0]{color:#028bb1}[_nghost-c0]{display:block;position:relative}html[_ngcontent-c1]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c1], [_ngcontent-c1]:after, [_ngcontent-c1]:before{-webkit-box-sizing:inherit;box-sizing:inherit}.invisible[_ngcontent-c1]{visibility:hidden!important}.hide[_ngcontent-c1]{display:none!important}.show[_ngcontent-c1]{display:block!important}.sr-only[_ngcontent-c1]{height:1px;width:1px;overflow:hidden;position:absolute!important;clip:rect(1px,1px,1px,1px)}.hidden-xs-up[_ngcontent-c1]{display:none!important}@media (max-width:479px){.hidden-xs-down[_ngcontent-c1]{display:none!important}}@media (min-width:480px){.hidden-sm-up[_ngcontent-c1]{display:none!important}}@media (max-width:767px){.hidden-sm-down[_ngcontent-c1]{display:none!important}}@media (min-width:768px){.hidden-md-up[_ngcontent-c1]{display:none!important}}@media (max-width:991px){.hidden-md-down[_ngcontent-c1]{display:none!important}}@media (min-width:992px){.hidden-lg-up[_ngcontent-c1]{display:none!important}}@media (max-width:1179px){.hidden-lg-down[_ngcontent-c1]{display:none!important}}@media (min-width:1180px){.hidden-xl-up[_ngcontent-c1]{display:none!important}}.hidden-xl-down[_ngcontent-c1], .visible-print-block[_ngcontent-c1]{display:none!important}@media print{.visible-print-block[_ngcontent-c1]{display:block!important}}.visible-print-inline[_ngcontent-c1]{display:none!important}@media print{.visible-print-inline[_ngcontent-c1]{display:inline!important}}.visible-print-inline-block[_ngcontent-c1]{display:none!important}@media print{.visible-print-inline-block[_ngcontent-c1]{display:inline-block!important}}@media print{.hidden-print[_ngcontent-c1]{display:none!important}}#contain-all[_ngcontent-c1]{width:100%;overflow:hidden;background:#fff;-webkit-backface-visibility:hidden;backface-visibility:hidden;-webkit-transform-style:preserve-3d}.outer_contain[_ngcontent-c1]{margin:0 auto;max-width:90rem}.contain[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto;padding-top:3rem;padding-bottom:3rem;padding-left:1.5rem;padding-right:1.5rem}.contain[_ngcontent-c1]:after{clear:both;content:"";display:table}@media screen and (min-width:48rem){.contain[_ngcontent-c1]{padding-top:6rem;padding-bottom:6rem}}@media screen and (min-width:73.75rem){.contain[_ngcontent-c1]{padding-left:0;padding-right:0}}.contain.no-padding[_ngcontent-c1]{padding:0}.contain.no-padding-top[_ngcontent-c1]{padding-top:0}.contain--none[_ngcontent-c1], .contain.no-padding-bottom[_ngcontent-c1]{padding-bottom:0}.contain--none[_ngcontent-c1]{padding-top:0;margin:0 auto}@media screen and (min-width:48rem){.contain--none[_ngcontent-c1]{padding-top:0;padding-bottom:0}}.contain--small[_ngcontent-c1]{padding-top:3rem;padding-bottom:3rem;margin:0 auto}@media screen and (min-width:48rem){.contain--small[_ngcontent-c1]{padding-top:4.5rem;padding-bottom:4.5rem}}.cards_contain[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto}.cards_contain[_ngcontent-c1]:after{clear:both;content:"";display:table}[_ngcontent-c1]:target:before{content:"";display:inline-block;height:130px;margin:-130px 0 0}.header[_ngcontent-c1]{max-width:100%;margin-left:auto;margin-right:auto}.header[_ngcontent-c1]:after{clear:both;content:"";display:table}.header.header--clone[_ngcontent-c1]{width:100%;top:-1000px}.header.header--clone[_ngcontent-c1]   .header__navbar[_ngcontent-c1]{height:4.5rem}.header.header--stick[_ngcontent-c1]{top:0;background-color:#fff;z-index:8000;-webkit-box-shadow:0 1px 2px rgba(0,0,0,.1);box-shadow:0 1px 2px rgba(0,0,0,.1)}.header__navbar[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto;height:4.5rem;padding:0 1.5em}.header__navbar[_ngcontent-c1]:after{clear:both;content:"";d ...
#
# html[_ngcontent-c14]{font-family:sans-serif;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}footer[_ngcontent-c14], header[_ngcontent-c14], nav[_ngcontent-c14], section[_ngcontent-c14]{display:block}a[_ngcontent-c14]{background:0 0;color:#1f8fc1;text-decoration:none}a[_ngcontent-c14]:active, a[_ngcontent-c14]:hover{outline:0}strong[_ngcontent-c14]{font-weight:700}h1[_ngcontent-c14]{margin:.67em 0}body[_ngcontent-c14]{background-color:#fff}img[_ngcontent-c14]{vertical-align:middle}svg[_ngcontent-c14]:not(:root){overflow:hidden}hr[_ngcontent-c14]{-webkit-box-sizing:content-box;box-sizing:content-box;height:0}input[_ngcontent-c14]{color:inherit;font:inherit;margin:0}input[type=submit][_ngcontent-c14]{-webkit-appearance:button;cursor:pointer}input[_ngcontent-c14]::-moz-focus-inner{border:0;padding:0}input[type=checkbox][_ngcontent-c14]{-webkit-box-sizing:border-box;box-sizing:border-box;padding:0}input[type=search][_ngcontent-c14]::-webkit-search-cancel-button, input[type=search][_ngcontent-c14]::-webkit-search-decoration{-webkit-appearance:none}*[_ngcontent-c14], [_ngcontent-c14]:after, [_ngcontent-c14]:before{-webkit-box-sizing:border-box;box-sizing:border-box}body[_ngcontent-c14]{margin:0;font-size:14px;line-height:1.7;color:#303030}input[_ngcontent-c14]{font-family:inherit;font-size:inherit;line-height:inherit}a[_ngcontent-c14]:focus, a[_ngcontent-c14]:hover{color:#145e7f}a[_ngcontent-c14]:focus{outline:thin dotted;outline:5px auto -webkit-focus-ring-color;outline-offset:-2px}.img-responsive[_ngcontent-c14]{display:block;max-width:100%;height:auto}hr[_ngcontent-c14]{margin-top:23px;margin-bottom:23px;border-top:1px solid #dcdcdc}.h4[_ngcontent-c14], h1[_ngcontent-c14], h3[_ngcontent-c14], h4[_ngcontent-c14], h6[_ngcontent-c14]{font-family:inherit;font-weight:700;line-height:1.1;color:inherit}h1[_ngcontent-c14], h3[_ngcontent-c14]{margin-top:23px}.h4[_ngcontent-c14], h1[_ngcontent-c14], h3[_ngcontent-c14], h4[_ngcontent-c14], h6[_ngcontent-c14]{margin-bottom:11.5px}.h4[_ngcontent-c14], h4[_ngcontent-c14], h6[_ngcontent-c14]{margin-top:11.5px}ul[_ngcontent-c14]{margin-top:0}h1[_ngcontent-c14]{font-size:28px}h3[_ngcontent-c14]{font-size:18px}.h4[_ngcontent-c14], h4[_ngcontent-c14], h6[_ngcontent-c14]{font-size:12px}ul[_ngcontent-c14]   ul[_ngcontent-c14]{margin-bottom:0}label[_ngcontent-c14]{font-weight:700}.small[_ngcontent-c14]{font-size:85%}.text-right[_ngcontent-c14]{text-align:right}.text-center[_ngcontent-c14]{text-align:center}.h4[_ngcontent-c14], .text-uppercase[_ngcontent-c14], h4[_ngcontent-c14]{text-transform:uppercase}ul[_ngcontent-c14]{margin-bottom:11.5px}@media (min-width:768px){.container[_ngcontent-c14]{width:750px}}.container[_ngcontent-c14]:after, .row[_ngcontent-c14]:after{clear:both}.container[_ngcontent-c14]{margin-right:auto;margin-left:auto;padding-left:15px;padding-right:15px}@media (min-width:992px){.container[_ngcontent-c14]{width:970px}}@media (min-width:1200px){.container[_ngcontent-c14]{width:1200px}}.row[_ngcontent-c14]{margin-left:-15px;margin-right:-15px}.col-sm-3[_ngcontent-c14], .col-sm-4[_ngcontent-c14], .col-sm-6[_ngcontent-c14], .col-sm-8[_ngcontent-c14], .col-sm-9[_ngcontent-c14], .col-sm-12[_ngcontent-c14], .col-xs-8[_ngcontent-c14], .col-xs-12[_ngcontent-c14]{position:relative;min-height:1px;padding-left:15px;padding-right:15px}.col-xs-8[_ngcontent-c14], .col-xs-12[_ngcontent-c14]{float:left}.col-xs-12[_ngcontent-c14]{width:100%}.col-xs-8[_ngcontent-c14]{width:66.66666667%}.col-xs-offset-2[_ngcontent-c14]{margin-left:16.66666667%}@media (min-width:768px){.col-sm-3[_ngcontent-c14], .col-sm-4[_ngcontent-c14], .col-sm-6[_ngcontent-c14], .col-sm-8[_ngcontent-c14], .col-sm-9[_ngcontent-c14], .col-sm-12[_ngcontent-c14]{float:left}.col-sm-12[_ngcontent-c14]{width:100%}.col-sm-9[_ngcontent-c14]{width:75%}.col-sm-8[_ngcontent-c14]{width:66.66666667%}.col-sm-6[_ngcontent-c14]{width:50%}.col-sm-4[_ngcontent-c14]{width:33.33333333%}.col-sm-3[_ngcontent-c14]{width:25%}.col-sm-offset-0[_ngconten ...
# .text-inverse[_ngcontent-c14]{color:#fff}@font-face{font-family:Whitney SSm A;src:url(data:application/x-font-woff;base64,...);font-weight:400;font-style:normal}@font-face{font-family:Whitney SSm B;src:url(data:application/x-font-woff;base64,...);font-weight:400;font-style:normal}@font-face{font-family:Whitney SSm A;src:url(data:application/x-font-woff;base64,...);font-weight:600;font-style:normal}@font-face{font-family:Whitney SSm B;src:url(data:application/x-font-woff;base64,...);font-weight:600;font-style:normal}[data-cloak][_ngcontent-c14]{display:none}.row.row-gap-medium[_ngcontent-c14]{margin-top:30px}.row.row-gap-large[_ngcontent-c14]{margin-top:45px}.section-inverse[_ngcontent-c14]{padding-top:60px;padding-bottom:60px}.section-inverse.section-small[_ngcontent-c14]{padding-top:30px;padding-bottom:30px}.section-inverse[_ngcontent-c14]{background-color:#4e4e4e}.section-inverse.section-inverse-standout-alternate[_ngcontent-c14]{background-color:#1f8fc1}.icon-level[_ngcontent-c14]{display:inline-block;height:12px;width:12px;margin-left:28px;background-color:#dcdcdc;position:relative}.icon-level[_ngcontent-c14]:after, .icon-level[_ngcontent-c14]:before{position:absolute;bottom:0;content:"";display:block;width:12px;background-color:inherit}.icon-level[_ngcontent-c14]:before{height:12px;left:-14px}.icon-level[_ngcontent-c14]:after{height:12px;left:-28px}.icon-level.icon-level-advanced[_ngcontent-c14], .icon-level.icon-level-anfänger[_ngcontent-c14]:after, .icon-level.icon-level-beginner[_ngcontent-c14]:after, .icon-level.icon-level-fortgeschrittene[_ngcontent-c14]:after, .icon-level.icon-level-fortgeschrittene[_ngcontent-c14]:before, .icon-level.icon-level-intermediate[_ngcontent-c14]:after, .icon-level.icon-level-intermediate[_ngcontent-c14]:before, .icon-level.icon-level-profis[_ngcontent-c14]{background-color:#666}.img-bordered[_ngcontent-c14]{border:1px solid #f3f3f3}.top_banner[_ngcontent-c14]{font-family:Open Sans,sans-serif}.top_banner[_ngcontent-c14]   p[_ngcontent-c14]   a[_ngcontent-c14]{text-decoration:none}.course-summary-card[_ngcontent-c14], .course-summary-card[_ngcontent-c14]   img[_ngcontent-c14]{-webkit-transition:opacity .3s ease-in;transition:opacity .3s ease-in}@media (max-width:767px){.course-summary-card[_ngcontent-c14]   h3[_ngcontent-c14]{text-align:center}.course-summary-card[_ngcontent-c14]   .badges[_ngcontent-c14]{display:block;text-align:center}}.contain[_ngcontent-c14]{margin:0 auto}.top_banner[_ngcontent-c14]{display:none;font-size:16px;-webkit-font-smoothing:antialiased;position:relative;background:#7d97ad;padding:.5em 1.5em;text-align:center}.top_banner[_ngcontent-c14]   p[_ngcontent-c14]{position:relative;color:#fff;font-size:.875em;margin:0;line-height:1.5em}.top_banner[_ngcontent-c14]   p[_ngcontent-c14]   a[_ngcontent-c14]{color:#fff;border-bottom:1px solid #91daee;-webkit-transition:color .3s ease;transition:color .3s ease}@media (min-width:30em){.top_banner[_ngcontent-c14]{padding:.5em 2.5em}.top_banner[_ngcontent-c14]   p[_ngcontent-c14]{line-height:2em}}@media (min-width:768px){footer[_ngcontent-c14]   .contain[_ngcontent-c14]{width:750px}}footer[_ngcontent-c14]{background:#f4f4ef;font-size:15px;font-family:Open Sans,sans-serif}footer[_ngcontent-c14]   .contain[_ngcontent-c14]{position:relative;overflow:hidden;padding:3.25em 1.5em 6.25em}@media (min-width:992px){footer[_ngcontent-c14]   .contain[_ngcontent-c14]{width:970px}}@media (min-width:1200px){footer[_ngcontent-c14]   .contain[_ngcontent-c14]{width:1170px}}@media (min-width:44em){footer[_ngcontent-c14]   .contain[_ngcontent-c14]{padding:6.25em 1.5em}}input[type=search][_ngcontent-c14]{font-size:14px;padding:.75em 1em;border-radius:.142857143em;border:1px solid #dbe2e8;outline:0;color:#2e3d49;-webkit-box-shadow:0 .25em .5em 0 rgba(46,61,73,.12);box-shadow:0 .25em .5em 0 rgba(46,61,73,.12);-webkit-transition:border .3s ease,-webkit-box-shadow .3s ease;transition:border .3s ease,-webkit-box-shadow .3s ease;transition:box-shadow .3s  ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "Nanodegree" is a registered trademark of Udacity. © 2011–2018 Udacity, Inc.Udacity is not an accredited university and we don't confer traditional degrees. Udacity Nanodegree programs represent collaborations with our industry partners who help us develop our content and who hire many of our program graduates. This website uses cookies to provide and improve our service as well customize your experience. By using this site, you agree to this use. Learn more{&amp;q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavLinks&amp;a;locale=en-EU&amp;q;:[{&amp;q;href&amp;q;:&amp;q;/nanodegree&amp;q;,&amp;q;text&amp;q;:&amp;q;Nanodegrees&amp;q;},{&amp;q;href&amp;q;:&amp;q;/courses/all&amp;q;,&amp;q;text&amp;q;:&amp;q;Free Courses&amp;q;},{&amp;q;href&amp;q;:&amp;q;https://www.udacity.com/business&amp;q;,&amp;q;text&amp;q;:&amp;q;For Business&amp;q;},{&amp;q;href&amp;q;:&amp;q;https://blog.udacity.com/&amp;q;,&amp;q;text&amp;q;:&amp;q;Blog&amp;q;}],&amp;q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavAuthMobileLinks&amp;a;locale=en-EU&amp;q;:{&amp;q;isAuth&amp;q;:[{&amp;q;text&amp;q;:&amp;q;
Remove HTML tags using Beautiful Soup library
soup = BeautifulSoup(r, "html.parser")
print(soup.get_text())
# Out:
# Catalog | Udacityhtml[_ngcontent-c0]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c0], [_ngcontent-c0]:after, [_ngcontent-c0]:before{-webkit-box-sizing:inherit;box-sizing:inherit}a[_ngcontent-c0]{color:#9400d3}body[_ngcontent-c0]{color:#028bb1}[_nghost-c0]{display:block;position:relative}html[_ngcontent-c1]{-webkit-box-sizing:border-box;box-sizing:border-box}*[_ngcontent-c1], [_ngcontent-c1]:after, [_ngcontent-c1]:before{-webkit-box-sizing:inherit;box-sizing:inherit}.invisible[_ngcontent-c1]{visibility:hidden!important}.hide[_ngcontent-c1]{display:none!important}.show[_ngcontent-c1]{display:block!important}.sr-only[_ngcontent-c1]{height:1px;width:1px;overflow:hidden;position:absolute!important;clip:rect(1px,1px,1px,1px)}.hidden-xs-up[_ngcontent-c1]{display:none!important}@media (max-width:479px){.hidden-xs-down[_ngcontent-c1]{display:none!important}}@media (min-width:480px){.hidden-sm-up[_ngcontent-c1]{display:none!important}}@media (max-width:767px){.hidden-sm-down[_ngcontent-c1]{display:none!important}}@media (min-width:768px){.hidden-md-up[_ngcontent-c1]{display:none!important}}@media (max-width:991px){.hidden-md-down[_ngcontent-c1]{display:none!important}}@media (min-width:992px){.hidden-lg-up[_ngcontent-c1]{display:none!important}}@media (max-width:1179px){.hidden-lg-down[_ngcontent-c1]{display:none!important}}@media (min-width:1180px){.hidden-xl-up[_ngcontent-c1]{display:none!important}}.hidden-xl-down[_ngcontent-c1], .visible-print-block[_ngcontent-c1]{display:none!important}@media print{.visible-print-block[_ngcontent-c1]{display:block!important}}.visible-print-inline[_ngcontent-c1]{display:none!important}@media print{.visible-print-inline[_ngcontent-c1]{display:inline!important}}.visible-print-inline-block[_ngcontent-c1]{display:none!important}@media print{.visible-print-inline-block[_ngcontent-c1]{display:inline-block!important}}@media print{.hidden-print[_ngcontent-c1]{display:none!important}}#contain-all[_ngcontent-c1]{width:100%;overflow:hidden;background:#fff;-webkit-backface-visibility:hidden;backface-visibility:hidden;-webkit-transform-style:preserve-3d}.outer_contain[_ngcontent-c1]{margin:0 auto;max-width:90rem}.contain[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto;padding-top:3rem;padding-bottom:3rem;padding-left:1.5rem;padding-right:1.5rem}.contain[_ngcontent-c1]:after{clear:both;content:"";display:table}@media screen and (min-width:48rem){.contain[_ngcontent-c1]{padding-top:6rem;padding-bottom:6rem}}@media screen and (min-width:73.75rem){.contain[_ngcontent-c1]{padding-left:0;padding-right:0}}.contain.no-padding[_ngcontent-c1]{padding:0}.contain.no-padding-top[_ngcontent-c1]{padding-top:0}.contain--none[_ngcontent-c1], .contain.no-padding-bottom[_ngcontent-c1]{padding-bottom:0}.contain--none[_ngcontent-c1]{padding-top:0;margin:0 auto}@media screen and (min-width:48rem){.contain--none[_ngcontent-c1]{padding-top:0;padding-bottom:0}}.contain--small[_ngcontent-c1]{padding-top:3rem;padding-bottom:3rem;margin:0 auto}@media screen and (min-width:48rem){.contain--small[_ngcontent-c1]{padding-top:4.5rem;padding-bottom:4.5rem}}.cards_contain[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto}.cards_contain[_ngcontent-c1]:after{clear:both;content:"";display:table}[_ngcontent-c1]:target:before{content:"";display:inline-block;height:130px;margin:-130px 0 0}.header[_ngcontent-c1]{max-width:100%;margin-left:auto;margin-right:auto}.header[_ngcontent-c1]:after{clear:both;content:"";display:table}.header.header--clone[_ngcontent-c1]{width:100%;top:-1000px}.header.header--clone[_ngcontent-c1]   .header__navbar[_ngcontent-c1]{height:4.5rem}.header.header--stick[_ngcontent-c1]{top:0;background-color:#fff;z-index:8000;-webkit-box-shadow:0 1px 2px rgba(0,0,0,.1);box-shadow:0 1px 2px rgba(0,0,0,.1)}.header__navbar[_ngcontent-c1]{max-width:73.75rem;margin-left:auto;margin-right:auto;height:4.5rem;padding:0 1.5em}.header__navbar[_ngcontent-c1]:after{clear:both;content:"";d ...
#
# html[_ngcontent-c14]{font-family:sans-serif;-ms-text-size-adjust:100%;-webkit-text-size-adjust:100%}footer[_ngcontent-c14], header[_ngcontent-c14], nav[_ngcontent-c14], section[_ngcontent-c14]{display:block}a[_ngcontent-c14]{background:0 0;color:#1f8fc1;text-decoration:none}a[_ngcontent-c14]:active, a[_ngcontent-c14]:hover{outline:0}strong[_ngcontent-c14]{font-weight:700}h1[_ngcontent-c14]{margin:.67em 0}body[_ngcontent-c14]{background-color:#fff}img[_ngcontent-c14]{vertical-align:middle}svg[_ngcontent-c14]:not(:root){overflow:hidden}hr[_ngcontent-c14]{-webkit-box-sizing:content-box;box-sizing:content-box;height:0}input[_ngcontent-c14]{color:inherit;font:inherit;margin:0}input[type=submit][_ngcontent-c14]{-webkit-appearance:button;cursor:pointer}input[_ngcontent-c14]::-moz-focus-inner{border:0;padding:0}input[type=checkbox][_ngcontent-c14]{-webkit-box-sizing:border-box;box-sizing:border-box;padding:0}input[type=search][_ngcontent-c14]::-webkit-search-cancel-button, input[type=search][_ngcontent-c14]::-webkit-search-decoration{-webkit-appearance:none}*[_ngcontent-c14], [_ngcontent-c14]:after, [_ngcontent-c14]:before{-webkit-box-sizing:border-box;box-sizing:border-box}body[_ngcontent-c14]{margin:0;font-size:14px;line-height:1.7;color:#303030}input[_ngcontent-c14]{font-family:inherit;font-size:inherit;line-height:inherit}a[_ngcontent-c14]:focus, a[_ngcontent-c14]:hover{color:#145e7f}a[_ngcontent-c14]:focus{outline:thin dotted;outline:5px auto -webkit-focus-ring-color;outline-offset:-2px}.img-responsive[_ngcontent-c14]{display:block;max-width:100%;height:auto}hr[_ngcontent-c14]{margin-top:23px;margin-bottom:23px;border-top:1px solid #dcdcdc}.h4[_ngcontent-c14], h1[_ngcontent-c14], h3[_ngcontent-c14], h4[_ngcontent-c14], h6[_ngcontent-c14]{font-family:inherit;font-weight:700;line-height:1.1;color:inherit}h1[_ngcontent-c14], h3[_ngcontent-c14]{margin-top:23px}.h4[_ngcontent-c14], h1[_ngcontent-c14], h3[_ngcontent-c14], h4[_ngcontent-c14], h6[_ngcontent-c14]{margin-bottom:11.5px}.h4[_ngcontent-c14], h4[_ngcontent-c14], h6[_ngcontent-c14]{margin-top:11.5px}ul[_ngcontent-c14]{margin-top:0}h1[_ngcontent-c14]{font-size:28px}h3[_ngcontent-c14]{font-size:18px}.h4[_ngcontent-c14], h4[_ngcontent-c14], h6[_ngcontent-c14]{font-size:12px}ul[_ngcontent-c14]   ul[_ngcontent-c14]{margin-bottom:0}label[_ngcontent-c14]{font-weight:700}.small[_ngcontent-c14]{font-size:85%}.text-right[_ngcontent-c14]{text-align:right}.text-center[_ngcontent-c14]{text-align:center}.h4[_ngcontent-c14], .text-uppercase[_ngcontent-c14], h4[_ngcontent-c14]{text-transform:uppercase}ul[_ngcontent-c14]{margin-bottom:11.5px}@media (min-width:768px){.container[_ngcontent-c14]{width:750px}}.container[_ngcontent-c14]:after, .row[_ngcontent-c14]:after{clear:both}.container[_ngcontent-c14]{margin-right:auto;margin-left:auto;padding-left:15px;padding-right:15px}@media (min-width:992px){.container[_ngcontent-c14]{width:970px}}@media (min-width:1200px){.container[_ngcontent-c14]{width:1200px}}.row[_ngcontent-c14]{margin-left:-15px;margin-right:-15px}.col-sm-3[_ngcontent-c14], .col-sm-4[_ngcontent-c14], .col-sm-6[_ngcontent-c14], .col-sm-8[_ngcontent-c14], .col-sm-9[_ngcontent-c14], .col-sm-12[_ngcontent-c14], .col-xs-8[_ngcontent-c14], .col-xs-12[_ngcontent-c14]{position:relative;min-height:1px;padding-left:15px;padding-right:15px}.col-xs-8[_ngcontent-c14], .col-xs-12[_ngcontent-c14]{float:left}.col-xs-12[_ngcontent-c14]{width:100%}.col-xs-8[_ngcontent-c14]{width:66.66666667%}.col-xs-offset-2[_ngcontent-c14]{margin-left:16.66666667%}@media (min-width:768px){.col-sm-3[_ngcontent-c14], .col-sm-4[_ngcontent-c14], .col-sm-6[_ngcontent-c14], .col-sm-8[_ngcontent-c14], .col-sm-9[_ngcontent-c14], .col-sm-12[_ngcontent-c14]{float:left}.col-sm-12[_ngcontent-c14]{width:100%}.col-sm-9[_ngcontent-c14]{width:75%}.col-sm-8[_ngcontent-c14]{width:66.66666667%}.col-sm-6[_ngcontent-c14]{width:50%}.col-sm-4[_ngcontent-c14]{width:33.33333333%}.col-sm-3[_ngcontent-c14]{width:25%}.col-sm-offset-0[_ngconten ...
# .text-inverse[_ngcontent-c14]{color:#fff}@font-face{font-family:Whitney SSm A;src:url(data:application/x-font-woff;base64,...);font-weight:400;font-style:normal}@font-face{font-family:Whitney SSm B;src:url(data:application/x-font-woff;base64,...);font-weight:400;font-style:normal}@font-face{font-family:Whitney SSm A;src:url(data:application/x-font-woff;base64,...);font-weight:600;font-style:normal}@font-face{font-family:Whitney SSm B;src:url(data:application/x-font-woff;base64,...);font-weight:600;font-style:normal}[data-cloak][_ngcontent-c14]{display:none}.row.row-gap-medium[_ngcontent-c14]{margin-top:30px}.row.row-gap-large[_ngcontent-c14]{margin-top:45px}.section-inverse[_ngcontent-c14]{padding-top:60px;padding-bottom:60px}.section-inverse.section-small[_ngcontent-c14]{padding-top:30px;padding-bottom:30px}.section-inverse[_ngcontent-c14]{background-color:#4e4e4e}.section-inverse.section-inverse-standout-alternate[_ngcontent-c14]{background-color:#1f8fc1}.icon-level[_ngcontent-c14]{display:inline-block;height:12px;width:12px;margin-left:28px;background-color:#dcdcdc;position:relative}.icon-level[_ngcontent-c14]:after, .icon-level[_ngcontent-c14]:before{position:absolute;bottom:0;content:"";display:block;width:12px;background-color:inherit}.icon-level[_ngcontent-c14]:before{height:12px;left:-14px}.icon-level[_ngcontent-c14]:after{height:12px;left:-28px}.icon-level.icon-level-advanced[_ngcontent-c14], .icon-level.icon-level-anfänger[_ngcontent-c14]:after, .icon-level.icon-level-beginner[_ngcontent-c14]:after, .icon-level.icon-level-fortgeschrittene[_ngcontent-c14]:after, .icon-level.icon-level-fortgeschrittene[_ngcontent-c14]:before, .icon-level.icon-level-intermediate[_ngcontent-c14]:after, .icon-level.icon-level-intermediate[_ngcontent-c14]:before, .icon-level.icon-level-profis[_ngcontent-c14]{background-color:#666}.img-bordered[_ngcontent-c14]{border:1px solid #f3f3f3}.top_banner[_ngcontent-c14]{font-family:Open Sans,sans-serif}.top_banner[_ngcontent-c14]   p[_ngcontent-c14]   a[_ngcontent-c14]{text-decoration:none}.course-summary-card[_ngcontent-c14], .course-summary-card[_ngcontent-c14]   img[_ngcontent-c14]{-webkit-transition:opacity .3s ease-in;transition:opacity .3s ease-in}@media (max-width:767px){.course-summary-card[_ngcontent-c14]   h3[_ngcontent-c14]{text-align:center}.course-summary-card[_ngcontent-c14]   .badges[_ngcontent-c14]{display:block;text-align:center}}.contain[_ngcontent-c14]{margin:0 auto}.top_banner[_ngcontent-c14]{display:none;font-size:16px;-webkit-font-smoothing:antialiased;position:relative;background:#7d97ad;padding:.5em 1.5em;text-align:center}.top_banner[_ngcontent-c14]   p[_ngcontent-c14]{position:relative;color:#fff;font-size:.875em;margin:0;line-height:1.5em}.top_banner[_ngcontent-c14]   p[_ngcontent-c14]   a[_ngcontent-c14]{color:#fff;border-bottom:1px solid #91daee;-webkit-transition:color .3s ease;transition:color .3s ease}@media (min-width:30em){.top_banner[_ngcontent-c14]{padding:.5em 2.5em}.top_banner[_ngcontent-c14]   p[_ngcontent-c14]{line-height:2em}}@media (min-width:768px){footer[_ngcontent-c14]   .contain[_ngcontent-c14]{width:750px}}footer[_ngcontent-c14]{background:#f4f4ef;font-size:15px;font-family:Open Sans,sans-serif}footer[_ngcontent-c14]   .contain[_ngcontent-c14]{position:relative;overflow:hidden;padding:3.25em 1.5em 6.25em}@media (min-width:992px){footer[_ngcontent-c14]   .contain[_ngcontent-c14]{width:970px}}@media (min-width:1200px){footer[_ngcontent-c14]   .contain[_ngcontent-c14]{width:1170px}}@media (min-width:44em){footer[_ngcontent-c14]   .contain[_ngcontent-c14]{padding:6.25em 1.5em}}input[type=search][_ngcontent-c14]{font-size:14px;padding:.75em 1em;border-radius:.142857143em;border:1px solid #dbe2e8;outline:0;color:#2e3d49;-webkit-box-shadow:0 .25em .5em 0 rgba(46,61,73,.12);box-shadow:0 .25em .5em 0 rgba(46,61,73,.12);-webkit-transition:border .3s ease,-webkit-box-shadow .3s ease;transition:border .3s ease,-webkit-box-shadow .3s ease;transition:box-shadow .3s  ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "Nanodegree" is a registered trademark of Udacity. © 2011–2018 Udacity, Inc.Udacity is not an accredited university and we don't confer traditional degrees. Udacity Nanodegree programs represent collaborations with our industry partners who help us develop our content and who hire many of our program graduates. This website uses cookies to provide and improve our service as well customize your experience. By using this site, you agree to this use. Learn more{&amp;q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavLinks&amp;a;locale=en-EU&amp;q;:[{&amp;q;href&amp;q;:&amp;q;/nanodegree&amp;q;,&amp;q;text&amp;q;:&amp;q;Nanodegrees&amp;q;},{&amp;q;href&amp;q;:&amp;q;/courses/all&amp;q;,&amp;q;text&amp;q;:&amp;q;Free Courses&amp;q;},{&amp;q;href&amp;q;:&amp;q;https://www.udacity.com/business&amp;q;,&amp;q;text&amp;q;:&amp;q;For Business&amp;q;},{&amp;q;href&amp;q;:&amp;q;https://blog.udacity.com/&amp;q;,&amp;q;text&amp;q;:&amp;q;Blog&amp;q;}],&amp;q;CORE_CLIENT_INJECT@CACHE_LOCALIZED_DATA-headerNavAuthMobileLinks&amp;a;locale=en-EU&amp;q;:{&amp;q;isAuth&amp;q;:[{&amp;q;text&amp;q;:&amp;q;
summaries[0]
# Out:
# <div _ngcontent-c14="" class="course-summary-card row row-gap-medium"><div _ngcontent-c14="" class="col-sm-3"><div _ngcontent-c14="" class="row"><div _ngcontent-c14="" class="col-xs-8 col-xs-offset-2 col-sm-12 col-sm-offset-0"><a _ngcontent-c14="" href="/course/intro-to-programming-nanodegree--nd000"><img _ngcontent-c14="" alt="Intro to Programming Nanodegree" class="img-responsive img-bordered center-block" height="170" src="https://s3-us-west-1.amazonaws.com/udacity-content/degrees/catalog-images/Intro-to-Programming.png" width="290"/></a></div></div></div><div _ngcontent-c14="" class="col-sm-9"><div _ngcontent-c14="" class="row"><div _ngcontent-c14="" class="col-sm-8"><h3 _ngcontent-c14="" class="h-slim"><a _ngcontent-c14="" href="/course/intro-to-programming-nanodegree--nd000"> Intro to Programming Nanodegree</a><span _ngcontent-c14="" class="badges"><!-- --></span></h3></div><div _ngcontent-c14="" class="col-sm-4 hidden-xs"><!-- --><span _ngcontent-c14="" class="caption text-right"><span _ngcontent-c14="" class="icon-level course-info-bar-icon icon-level-beginner" data-course-level-icon=""></span><span _ngcontent-c14="" data-course-level-label="">beginner</span></span></div></div><div _ngcontent-c14=""><!-- --><span _ngcontent-c14="">Udacity's Intro to Programming is your first step towards careers in Web and App Development, Machine Learning, Data Science, AI, and more! This program is perfect for beginners.</span></div><!-- --></div></div>

# %%
# Extract title
summaries[0].select_one("h3 a").get_text().strip()
# Out:
# 'Intro to Programming Nanodegree'

# %%
# Extract description
summaries[0].find_all('span')[-1].get_text().strip()
# Out:
# "Udacity's Intro to Programming is your first step towards careers in Web and App Development, Machine Learning, Data Science, AI, and more! This program is perfect for beginners."

# %%
# Find all course summaries, extract title and description
courses = []
summaries = soup.find_all("div", class_="course-summary-card")
for summary in summaries:
    title = summary.select_one("h3 a").get_text().strip()
    description = summary.find_all('span')[-1].get_text().strip()
    courses.append((title, description))

print(len(courses), "course summaries found. Sample:")
print(courses[0][0])
print(courses[0][1])
# Out:
# 10 course summaries found. Sample:
# Intro to Programming Nanodegree
# Udacity's Intro to Programming is your first step towards careers in Web and App Development, Machine Learning, Data Science, AI, and more! This program is perfect for beginners.

# %% [markdown]
# ## Normalization

# %% [markdown]
# ### Case Normalization

# %%
# Sample text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"
print(text)
# Out:
# The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?

# %%
# Convert to lowercase
text = text.lower() 
print(text)
# Out:
# the first time you see the second renaissance it may look boring. look at it at least twice and definitely watch part 2. it will change your view of the matrix. are the human people the ones who started the war ? is ai a bad thing ?

# %% [markdown]
# ### Punctuation Removal

# %%
import re

# Remove punctuation characters
text = re.sub(r"[^a-zA-Z0-9]", " ", text) 
print(text)
# Out:
# the first time you see the second renaissance it may look boring  look at it at least twice and definitely watch part 2  it will change your view of the matrix  are the human people the ones who started the war   is ai a bad thing

# %% [markdown]
# ## Tokenization

# %%
# Split text into tokens (words)
words = text.split()
print(words)
# Out:
# ['the', 'first', 'time', 'you', 'see', 'the', 'second', 'renaissance', 'it', 'may', 'look', 'boring', 'look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2', 'it', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix', 'are', 'the', 'human', 'people', 'the', 'ones', 'who', 'started', 'the', 'war', 'is', 'ai', 'a', 'bad', 'thing']

# %% [markdown]
# ### NLTK: Natural Language ToolKit

# %%
# Another sample text
text = "Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers."
print(text)
# Out:
# Dr. Smith graduated from the University of Washington. He later started an analytics firm called Lux, which catered to enterprise customers.

# %%
from nltk.tokenize import word_tokenize
nltk.data.path.append('/home/sabau/IdeaProjects/term2/AIND-NLP/data')

# Split text into words using NLTK
words = word_tokenize(text)
print(words)
# Out:
# ['Dr.', 'Smith', 'graduated', 'from', 'the', 'University', 'of', 'Washington', '.', 'He', 'later', 'started', 'an', 'analytics', 'firm', 'called', 'Lux', ',', 'which', 'catered', 'to', 'enterprise', 'customers', '.']

# %%
from nltk.tokenize import sent_tokenize

# Split text into sentences
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['Dr. Smith graduated from the University of Washington.', 'He later started an analytics firm called Lux, which catered to enterprise customers.']

# %%
# List stop words
from nltk.corpus import stopwords
print(stopwords.words("english"))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# Reset text
text = "The first time you see The Second Renaissance it may look boring. Look at it at least twice and definitely watch part 2. It will change your view of the matrix. Are the human people the ones who started the war ? Is AI a bad thing ?"

# Normalize it
text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower())

# Tokenize it
words = text.split()
print(words)
# Out:
# ['the', 'first', 'time', 'you', 'see', 'the', 'second', 'renaissance', 'it', 'may', 'look', 'boring', 'look', 'at', 'it', 'at', 'least', 'twice', 'and', 'definitely', 'watch', 'part', '2', 'it', 'will', 'change', 'your', 'view', 'of', 'the', 'matrix', 'are', 'the', 'human', 'people', 'the', 'ones', 'who', 'started', 'the', 'war', 'is', 'ai', 'a', 'bad', 'thing']

# %%
# Remove stop words
words = [w for w in words if w not in stopwords.words("english")]
print(words)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'boring', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'ones', 'started', 'war', 'ai', 'bad', 'thing']

# %% [markdown]
# ## Part-of-Speech Tagging

# %%
from nltk import pos_tag

# Tag parts of speech (PoS)
sentence = word_tokenize("I always lie down to tell a lie.")
pos_tag(sentence)
# Out:
# [('I', 'PRP'),
#  ('always', 'RB'),
#  ('lie', 'VBP'),
#  ('down', 'RP'),
#  ('to', 'TO'),
#  ('tell', 'VB'),
#  ('a', 'DT'),
#  ('lie', 'NN'),
#  ('.', '.')]

# %% [markdown]
# ### Sentence Parsing

# %%
import nltk

# Define a custom grammar
my_grammar = nltk.CFG.fromstring("""
S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
P -> 'in'
""")
parser = nltk.ChartParser(my_grammar)

# Parse a sentence
sentence = word_tokenize("I shot an elephant in my pajamas")
for tree in parser.parse(sentence):
    print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))

# %%
import IPython  # for displaying parse trees inline

# Visualize parse trees
for tree in parser.parse(sentence):
    IPython.display.display(tree)  # instead of tree.draw()
# Out:
# Tree('S', [Tree('NP', ['I']), Tree('VP', [Tree('VP', [Tree('V', ['shot']), Tree('NP', [Tree('Det', ['an']), Tree('N', ['elephant'])])]), Tree('PP', [Tree('P', ['in']), Tree('NP', [Tree('Det', ['my']), Tree('N', ['pajamas'])])])])])
# Tree('S', [Tree('NP', ['I']), Tree('VP', [Tree('V', ['shot']), Tree('NP', [Tree('Det', ['an']), Tree('N', ['elephant']), Tree('PP', [Tree('P', ['in']), Tree('NP', [Tree('Det', ['my']), Tree('N', ['pajamas'])])])])])])

# %%
from nltk import pos_tag, ne_chunk
from nltk.tokenize import word_tokenize

# Recognize named entities in a tagged sentence
tree = ne_chunk(pos_tag(word_tokenize("Antonio joined Udacity Inc. in California.")))
IPython.display.display(tree)
# Out:
# Tree('S', [Tree('PERSON', [('Antonio', 'NNP')]), ('joined', 'VBD'), Tree('ORGANIZATION', [('Udacity', 'NNP'), ('Inc.', 'NNP')]), ('in', 'IN'), Tree('GPE', [('California', 'NNP')]), ('.', '.')])

# %% [markdown]
# ## Stemming & Lemmatization
#
# ### Stemming

# %%
from nltk.stem.porter import PorterStemmer

# Reduce words to their stems
stemmed = [PorterStemmer().stem(w) for w in words]
print(stemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaiss', 'may', 'look', 'bore', 'look', 'least', 'twice', 'definit', 'watch', 'part', '2', 'chang', 'view', 'matrix', 'human', 'peopl', 'one', 'start', 'war', 'ai', 'bad', 'thing']

# %% [markdown]
# ### Lemmatization

# %%
from nltk.stem.wordnet import WordNetLemmatizer

# Reduce words to their root form
lemmed = [WordNetLemmatizer().lemmatize(w) for w in words]
print(lemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'boring', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'one', 'started', 'war', 'ai', 'bad', 'thing']

# %%
# Lemmatize verbs by specifying pos
lemmed = [WordNetLemmatizer().lemmatize(w, pos='v') for w in lemmed]
print(lemmed)
# Out:
# ['first', 'time', 'see', 'second', 'renaissance', 'may', 'look', 'bore', 'look', 'least', 'twice', 'definitely', 'watch', 'part', '2', 'change', 'view', 'matrix', 'human', 'people', 'one', 'start', 'war', 'ai', 'bad', 'thing']
